# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import tensorflow.keras.backend as K
# Out:
# /Users/clawsy/Documents/geoelements_dev/xai-cpt/.venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
data_path = 'data'
model_path = 'model'
output_path = 'output'

# %%
ic_data = np.load(f'{data_path}/ic_5cm_v3.npy')
qc_data = np.load(f'{data_path}/qc_5cm_v3.npy')
id_data = np.load(f'{data_path}/id_5cm_v3.npy')

mask = np.alltrue(ic_data<=5, axis=1)
id_data = id_data[mask]
ic_data = ic_data[mask]
qc_data = qc_data[mask]
print(ic_data.shape)
print(qc_data.shape)
# Out:
# (12475, 200)
# (12475, 200)

# %%
which = 'ic'
if which == 'ic':
  vmax = 5
  scale = 5
  X = ic_data.reshape(-1,10,20)/scale
elif which == 'qc':
  vmax = 254
  scale = 254
  X = qc_data.reshape(-1,10,20)/scale
else:
  X = np.stack((ic_data/5, qc_data/254),axis=1)
# split data into 80-20 of training and testing set
X_train, X_valid_test = train_test_split(X, test_size=0.3, random_state=0)
X_valid, X_test = train_test_split(X_valid_test, test_size=0.5, random_state=0)

# %%
# create depth array
depth = np.linspace(0,10,200)

# %%
# demo of reshaping CPT profile
n_seq = X_train.shape[-2]
d_model = X_train.shape[-1]
print(n_seq, d_model)

fig, ax = plt.subplots(figsize=(6,8))
im = plt.imshow(X_train[0]*scale)
plt.colorbar(mappable=im, ax=ax,fraction=0.046, pad=0.04,shrink=0.4,label='$I_c$')
plt.ylabel('Sequence')
plt.xlabel('Features')
plt.xticks(np.arange(d_model))
plt.yticks(np.arange(n_seq))
plt.savefig(f'{output_path}/reshaped_ic.png',dpi=200)
plt.show()
# Out:
# 10 20

# %%
# demo2 of reshaping CPT profile
fig, ax = plt.subplots(1,2, figsize=(6,6))
ax[0].plot(X_train[0].reshape(-1)*scale,depth)
ax[0].set_xlim(0,vmax)
ax[0].set_ylim(10,0)
ax[0].set_xlabel('$q_{c1ncs}$')
ax[0].set_ylabel('Depth(m)')
ax[1].imshow(X_train[0])
ax[1].set_aspect(5)
ax[1].set_yticks([0,2,4,6,8],['0~1 m','2~3 m','4~5 m','6~7 m','8~9 m'])
#ax[1].set_yticklabels()
ax[1].set_xticks([0,5,10,15],[0,25,50,75])
ax[1].set_xlabel('cm')
plt.tight_layout()

# %% [markdown]
# ## Self-attention AE

# %%
# set up seed
np.random.seed(0)
tf.random.set_seed(0)

# %%
# positional encoding
def positional_encoding(length, depth):
  scale=1
  depth = depth/2

  positions = np.arange(length)[:, np.newaxis]     # (seq, 1)
  depths = np.arange(depth)[np.newaxis, :]/depth   # (1, depth)

  angle_rates = 1 / (10000**depths)         # (1, depth)
  angle_rads = positions * angle_rates      # (pos, depth)
  pos_encoding = np.concatenate(
      [np.sin(angle_rads), np.cos(angle_rads)],
      axis=-1)*scale
  return tf.cast(pos_encoding, dtype=tf.float32)

# %%
# define sampling if using variational autoencoder
def sampling(args):
    z_mean, z_log_sigma = args
    epsilon = tf.keras.backend.random_normal(shape=(tf.shape(z_mean)[0], tf.shape(z_mean)[1]),
                              mean=0., stddev=0.1)
    return z_mean + tf.exp(z_log_sigma) * epsilon

# %%
# demo of positional encoding
n_seq = X_train.shape[-2]
d_model = X_train.shape[-1]
# plot positional encoding
pos_code = positional_encoding(n_seq,d_model).numpy()
#pos_code = pos_code[:n_seq,:d_model]
im = plt.imshow(pos_code, vmin=-1)
print(pos_code.shape)
plt.ylabel('Position $pos$', fontsize=12)
plt.xlabel('Feature $i$')
plt.xticks(np.arange(d_model))
plt.yticks(np.arange(n_seq))
plt.title('Positional Encoding', fontsize=15)
plt.colorbar(im,fraction=0.046, pad=0.04,shrink=0.7,label='PE')
plt.show()
# Out:
# (10, 20)

# %%
# define the model, we only use one AT block for encoder and decoder
def make_SAE(latent_dim, initial_heads=1, intermediate_heads=1, vari=False, reconstr_factor=1):
  #keras.backend.clear_session()

  # Create encoder
  inputs = keras.Input(shape=(n_seq, d_model), name='enc_input')

  pos_code = positional_encoding(n_seq,d_model)
  x = inputs + pos_code
  # encoder attention block 1
  enc_at1, w = keras.layers.MultiHeadAttention(num_heads=initial_heads, key_dim=d_model, dropout=0.1, name='enc_at1')(x, x, return_attention_scores=True)
  x = keras.layers.Add()([inputs, enc_at1])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
  dense = keras.layers.Dense(256, activation='relu')(x)
  dense = keras.layers.Dense(d_model)(dense)
  x = keras.layers.Add()([x , dense])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
  '''
  # encoder attention block 2
  enc_at2 = keras.layers.MultiHeadAttention(num_heads=intermediate_heads, key_dim=d_model, dropout=0.1, name='enc_at2')(x, x)
  x = keras.layers.Add()([x, enc_at2])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
  dense = keras.layers.Dense(256, activation='relu')(x)
  dense = keras.layers.Dense(d_model)(dense)
  x = keras.layers.Add()([x , dense])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)

  # encoder attention block 3
  enc_at3 = keras.layers.MultiHeadAttention(num_heads=intermediate_heads, key_dim=d_model, dropout=0.1, name='enc_at3')(x, x)
  x = keras.layers.Add()([x, enc_at3])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
  dense = keras.layers.Dense(256, activation='relu')(x)
  dense = keras.layers.Dense(d_model)(dense)
  x = keras.layers.Add()([x , dense])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)

  # encoder attention block 4
  enc_at4 = keras.layers.MultiHeadAttention(num_heads=intermediate_heads, key_dim=d_model, dropout=0.1, name='enc_at4')(x, x)
  x = keras.layers.Add()([x, enc_at4])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
  dense = keras.layers.Dense(256, activation='relu')(x)
  dense = keras.layers.Dense(d_model)(dense)
  x = keras.layers.Add()([x , dense])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)'''

  x = keras.layers.Flatten()(x)
  if vari:
    z_mean = keras.layers.Dense(latent_dim, name="z_mean")(x)
    z_log_var = keras.layers.Dense(latent_dim, name="z_log_var")(x)
    #z = Sampling()([z_mean, z_log_var])
    z = keras.layers.Lambda(sampling)([z_mean, z_log_var])
    encoder = keras.Model(inputs, [z_mean, z_log_var, z], name="encoder")
  else:
    latent = keras.layers.Dense(latent_dim)(x)
    encoder = keras.Model(inputs, latent, name='encoder')
  # Create decoder
  latent_inputs = keras.Input(shape=(latent_dim,), name='dec_input')

  x = keras.layers.Dense(n_seq*d_model)(latent_inputs)
  x = keras.layers.Reshape((n_seq,d_model), name='reshape')(x)

  '''# decoder attention block 1
  dec_at1 = keras.layers.MultiHeadAttention(num_heads=intermediate_heads, key_dim=d_model, name='dec_at1')(x, x)
  x = keras.layers.Add()([x, dec_at1])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
  dense = keras.layers.Dense(256, activation='relu')(x)
  dense = keras.layers.Dense(d_model)(dense)
  x = keras.layers.Add()([x , dense])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
  # decoder attention block 2
  dec_at2 = keras.layers.MultiHeadAttention(num_heads=intermediate_heads, key_dim=d_model, name='dec_at2')(x, x)
  x = keras.layers.Add()([x, dec_at2])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
  dense = keras.layers.Dense(256, activation='relu')(x)
  dense = keras.layers.Dense(d_model)(dense)
  x = keras.layers.Add()([x , dense])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
  # decoder attention block 3
  dec_at3 = keras.layers.MultiHeadAttention(num_heads=intermediate_heads, key_dim=d_model, name='dec_at3')(x, x)
  x = keras.layers.Add()([x, dec_at3])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
  dense = keras.layers.Dense(256, activation='relu')(x)
  dense = keras.layers.Dense(d_model)(dense)
  x = keras.layers.Add()([x , dense])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)'''
  # decoder attention block 4
  dec_at4 = keras.layers.MultiHeadAttention(num_heads=intermediate_heads, key_dim=d_model, name='dec_at4')(x, x)
  x = keras.layers.Add()([x, dec_at4])
  x = keras.layers.LayerNormalization(epsilon=1e-6)(x)
  dense = keras.layers.Dense(256, activation='relu')(x)
  dense = keras.layers.Dense(d_model)(dense)
  x = keras.layers.Add()([x , dense])
  outputs = keras.layers.LayerNormalization(epsilon=1e-6)(x)
  #outputs = keras.layers.Activation('relu')(x) # or relu

  decoder = keras.Model(latent_inputs, outputs, name='decoder')

  # instantiate SAE model
  if vari:
    outputs = decoder(encoder(inputs)[2])
    sae = keras.Model(inputs, outputs, name='sae')

    reconstruction_loss = keras.losses.mse(inputs, outputs)
    kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
    kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
    total_loss = reconstr_factor*reconstruction_loss + 0.0001*kl_loss

    sae.add_loss(total_loss)
    sae.compile(optimizer='adam') # adam, SGD
  else:
    outputs = decoder(encoder(inputs))
    sae = keras.Model(inputs, outputs, name='sae')
    sae.compile(optimizer='adam', loss='mse')
  return encoder, decoder, sae

# %% [markdown]
# ## Training

# %%
# define training hyperparameters
vari = False
reconstr_factor = 1
latent_dim = 10

original_dim = n_seq * d_model
initial_heads = 3
intermediate_heads = 5
epochs = 400

# %%
import random
tf.keras.backend.clear_session()
random.seed(0)
np.random.seed(0)
tf.random.set_seed(0)
# create model
enc, dec, sae = make_SAE(latent_dim=latent_dim, initial_heads=initial_heads,intermediate_heads=intermediate_heads, vari=vari, reconstr_factor=reconstr_factor)
sae.summary()
# Out:
# Model: "sae"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  enc_input (InputLayer)      [(None, 10, 20)]          0
#
#  encoder (Functional)        (None, 10)                17606
#
#  decoder (Functional)        (None, 10, 20)            21116
#
# =================================================================
# Total params: 38722 (151.26 KB)
# Trainable params: 38722 (151.26 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# fit model
fit_sae = sae.fit(X_train, X_train,
        epochs=epochs,
        batch_size=128,
        validation_data=(X_valid, X_valid),
        verbose=2)
# Out:
# Epoch 1/400
# 69/69 - 1s - loss: 1.0105 - val_loss: 0.8665 - 1s/epoch - 22ms/step
# Epoch 2/400
# 69/69 - 1s - loss: 0.7446 - val_loss: 0.6223 - 730ms/epoch - 11ms/step
# Epoch 3/400
# 69/69 - 1s - loss: 0.5241 - val_loss: 0.4321 - 817ms/epoch - 12ms/step
# Epoch 4/400
# 69/69 - 1s - loss: 0.3655 - val_loss: 0.3036 - 816ms/epoch - 12ms/step
# Epoch 5/400
# 69/69 - 1s - loss: 0.2578 - val_loss: 0.2146 - 811ms/epoch - 12ms/step
# Epoch 6/400
# 69/69 - 1s - loss: 0.1820 - val_loss: 0.1511 - 815ms/epoch - 12ms/step
# Epoch 7/400
# 69/69 - 1s - loss: 0.1278 - val_loss: 0.1056 - 815ms/epoch - 12ms/step
# Epoch 8/400
# 69/69 - 1s - loss: 0.0890 - val_loss: 0.0733 - 812ms/epoch - 12ms/step
# Epoch 9/400
# 69/69 - 1s - loss: 0.0617 - val_loss: 0.0507 - 819ms/epoch - 12ms/step
# Epoch 10/400
# 69/69 - 1s - loss: 0.0427 - val_loss: 0.0352 - 824ms/epoch - 12ms/step
# Epoch 11/400
# 69/69 - 1s - loss: 0.0298 - val_loss: 0.0248 - 818ms/epoch - 12ms/step
# Epoch 12/400
# 69/69 - 1s - loss: 0.0213 - val_loss: 0.0181 - 811ms/epoch - 12ms/step
# Epoch 13/400
# 69/69 - 1s - loss: 0.0158 - val_loss: 0.0138 - 823ms/epoch - 12ms/step
# Epoch 14/400
# 69/69 - 1s - loss: 0.0124 - val_loss: 0.0112 - 817ms/epoch - 12ms/step
# Epoch 15/400
# 69/69 - 1s - loss: 0.0104 - val_loss: 0.0096 - 817ms/epoch - 12ms/step
# Epoch 16/400
# 69/69 - 1s - loss: 0.0092 - val_loss: 0.0087 - 811ms/epoch - 12ms/step
# Epoch 17/400
# 69/69 - 1s - loss: 0.0085 - val_loss: 0.0082 - 820ms/epoch - 12ms/step
# Epoch 18/400
# 69/69 - 1s - loss: 0.0081 - val_loss: 0.0080 - 813ms/epoch - 12ms/step
# Epoch 19/400
# 69/69 - 1s - loss: 0.0079 - val_loss: 0.0078 - 821ms/epoch - 12ms/step
# Epoch 20/400
# 69/69 - 1s - loss: 0.0078 - val_loss: 0.0078 - 814ms/epoch - 12ms/step
# Epoch 21/400
# 69/69 - 1s - loss: 0.0078 - val_loss: 0.0078 - 811ms/epoch - 12ms/step
# Epoch 22/400
# 69/69 - 1s - loss: 0.0078 - val_loss: 0.0077 - 817ms/epoch - 12ms/step
# Epoch 23/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 853ms/epoch - 12ms/step
# Epoch 24/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 836ms/epoch - 12ms/step
# Epoch 25/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 831ms/epoch - 12ms/step
# Epoch 26/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 848ms/epoch - 12ms/step
# Epoch 27/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 838ms/epoch - 12ms/step
# Epoch 28/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 825ms/epoch - 12ms/step
# Epoch 29/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 831ms/epoch - 12ms/step
# Epoch 30/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 826ms/epoch - 12ms/step
# Epoch 31/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 831ms/epoch - 12ms/step
# Epoch 32/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 850ms/epoch - 12ms/step
# Epoch 33/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 860ms/epoch - 12ms/step
# Epoch 34/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 829ms/epoch - 12ms/step
# Epoch 35/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 833ms/epoch - 12ms/step
# Epoch 36/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 826ms/epoch - 12ms/step
# Epoch 37/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 809ms/epoch - 12ms/step
# Epoch 38/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 815ms/epoch - 12ms/step
# Epoch 39/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 821ms/epoch - 12ms/step
# Epoch 40/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 826ms/epoch - 12ms/step
# Epoch 41/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 810ms/epoch - 12ms/step
# Epoch 42/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 808ms/epoch - 12ms/step
# Epoch 43/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 808ms/epoch - 12ms/step
# Epoch 44/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 809ms/epoch - 12ms/step
# Epoch 45/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 851ms/epoch - 12ms/step
# Epoch 46/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 834ms/epoch - 12ms/step
# Epoch 47/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0077 - 821ms/epoch - 12ms/step
# Epoch 48/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0076 - 804ms/epoch - 12ms/step
# Epoch 49/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0076 - 813ms/epoch - 12ms/step
# Epoch 50/400
# 69/69 - 1s - loss: 0.0077 - val_loss: 0.0076 - 815ms/epoch - 12ms/step
# Epoch 51/400
# 69/69 - 1s - loss: 0.0076 - val_loss: 0.0076 - 816ms/epoch - 12ms/step
# Epoch 52/400
# 69/69 - 1s - loss: 0.0076 - val_loss: 0.0076 - 812ms/epoch - 12ms/step
# Epoch 53/400
# 69/69 - 1s - loss: 0.0076 - val_loss: 0.0076 - 842ms/epoch - 12ms/step
# Epoch 54/400
# 69/69 - 1s - loss: 0.0076 - val_loss: 0.0076 - 817ms/epoch - 12ms/step
# Epoch 55/400
# 69/69 - 1s - loss: 0.0076 - val_loss: 0.0076 - 816ms/epoch - 12ms/step
# Epoch 56/400
# 69/69 - 1s - loss: 0.0076 - val_loss: 0.0076 - 812ms/epoch - 12ms/step
# Epoch 57/400
# 69/69 - 1s - loss: 0.0076 - val_loss: 0.0076 - 813ms/epoch - 12ms/step
# Epoch 58/400
# 69/69 - 1s - loss: 0.0076 - val_loss: 0.0076 - 820ms/epoch - 12ms/step
# Epoch 59/400
# 69/69 - 1s - loss: 0.0076 - val_loss: 0.0076 - 809ms/epoch - 12ms/step
# Epoch 60/400
# 69/69 - 1s - loss: 0.0076 - val_loss: 0.0075 - 814ms/epoch - 12ms/step
# Epoch 61/400
# 69/69 - 1s - loss: 0.0076 - val_loss: 0.0075 - 817ms/epoch - 12ms/step
# Epoch 62/400
# 69/69 - 1s - loss: 0.0075 - val_loss: 0.0075 - 825ms/epoch - 12ms/step
# Epoch 63/400
# 69/69 - 1s - loss: 0.0075 - val_loss: 0.0075 - 809ms/epoch - 12ms/step
# Epoch 64/400
# 69/69 - 1s - loss: 0.0075 - val_loss: 0.0074 - 813ms/epoch - 12ms/step
# Epoch 65/400
# 69/69 - 1s - loss: 0.0074 - val_loss: 0.0074 - 845ms/epoch - 12ms/step
# Epoch 66/400
# 69/69 - 1s - loss: 0.0074 - val_loss: 0.0073 - 823ms/epoch - 12ms/step
# Epoch 67/400
# 69/69 - 1s - loss: 0.0073 - val_loss: 0.0072 - 826ms/epoch - 12ms/step
# Epoch 68/400
# 69/69 - 1s - loss: 0.0072 - val_loss: 0.0071 - 814ms/epoch - 12ms/step
# Epoch 69/400
# 69/69 - 1s - loss: 0.0070 - val_loss: 0.0068 - 808ms/epoch - 12ms/step
# Epoch 70/400
# 69/69 - 1s - loss: 0.0067 - val_loss: 0.0065 - 823ms/epoch - 12ms/step
# Epoch 71/400
# 69/69 - 1s - loss: 0.0063 - val_loss: 0.0061 - 816ms/epoch - 12ms/step
# Epoch 72/400
# 69/69 - 1s - loss: 0.0059 - val_loss: 0.0056 - 825ms/epoch - 12ms/step
# Epoch 73/400
# 69/69 - 1s - loss: 0.0054 - val_loss: 0.0051 - 823ms/epoch - 12ms/step
# Epoch 74/400
# 69/69 - 1s - loss: 0.0049 - val_loss: 0.0047 - 833ms/epoch - 12ms/step
# Epoch 75/400
# 69/69 - 1s - loss: 0.0044 - val_loss: 0.0042 - 850ms/epoch - 12ms/step
# Epoch 76/400
# 69/69 - 1s - loss: 0.0040 - val_loss: 0.0038 - 841ms/epoch - 12ms/step
# Epoch 77/400
# 69/69 - 1s - loss: 0.0037 - val_loss: 0.0037 - 885ms/epoch - 13ms/step
# Epoch 78/400
# 69/69 - 1s - loss: 0.0034 - val_loss: 0.0032 - 889ms/epoch - 13ms/step
# Epoch 79/400
# 69/69 - 1s - loss: 0.0031 - val_loss: 0.0029 - 880ms/epoch - 13ms/step
# Epoch 80/400
# 69/69 - 1s - loss: 0.0028 - val_loss: 0.0027 - 893ms/epoch - 13ms/step
# Epoch 81/400
# 69/69 - 1s - loss: 0.0026 - val_loss: 0.0025 - 851ms/epoch - 12ms/step
# Epoch 82/400
# 69/69 - 1s - loss: 0.0024 - val_loss: 0.0024 - 848ms/epoch - 12ms/step
# Epoch 83/400
# 69/69 - 1s - loss: 0.0023 - val_loss: 0.0023 - 857ms/epoch - 12ms/step
# Epoch 84/400
# 69/69 - 1s - loss: 0.0023 - val_loss: 0.0022 - 865ms/epoch - 13ms/step
# Epoch 85/400
# 69/69 - 1s - loss: 0.0022 - val_loss: 0.0022 - 830ms/epoch - 12ms/step
# Epoch 86/400
# 69/69 - 1s - loss: 0.0022 - val_loss: 0.0022 - 867ms/epoch - 13ms/step
# Epoch 87/400
# 69/69 - 1s - loss: 0.0022 - val_loss: 0.0021 - 872ms/epoch - 13ms/step
# Epoch 88/400
# 69/69 - 1s - loss: 0.0022 - val_loss: 0.0021 - 845ms/epoch - 12ms/step
# Epoch 89/400
# 69/69 - 1s - loss: 0.0021 - val_loss: 0.0021 - 870ms/epoch - 13ms/step
# Epoch 90/400
# 69/69 - 1s - loss: 0.0021 - val_loss: 0.0021 - 841ms/epoch - 12ms/step
# Epoch 91/400
# 69/69 - 1s - loss: 0.0021 - val_loss: 0.0021 - 820ms/epoch - 12ms/step
# Epoch 92/400
# 69/69 - 1s - loss: 0.0021 - val_loss: 0.0021 - 886ms/epoch - 13ms/step
# Epoch 93/400
# 69/69 - 1s - loss: 0.0021 - val_loss: 0.0021 - 832ms/epoch - 12ms/step
# Epoch 94/400
# 69/69 - 1s - loss: 0.0021 - val_loss: 0.0021 - 837ms/epoch - 12ms/step
# Epoch 95/400
# 69/69 - 1s - loss: 0.0021 - val_loss: 0.0020 - 857ms/epoch - 12ms/step
# Epoch 96/400
# 69/69 - 1s - loss: 0.0021 - val_loss: 0.0020 - 837ms/epoch - 12ms/step
# Epoch 97/400
# 69/69 - 1s - loss: 0.0021 - val_loss: 0.0021 - 865ms/epoch - 13ms/step
# Epoch 98/400
# 69/69 - 1s - loss: 0.0021 - val_loss: 0.0020 - 872ms/epoch - 13ms/step
# Epoch 99/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 843ms/epoch - 12ms/step
# Epoch 100/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 841ms/epoch - 12ms/step
# Epoch 101/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 847ms/epoch - 12ms/step
# Epoch 102/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 827ms/epoch - 12ms/step
# Epoch 103/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 845ms/epoch - 12ms/step
# Epoch 104/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 878ms/epoch - 13ms/step
# Epoch 105/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 842ms/epoch - 12ms/step
# Epoch 106/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 829ms/epoch - 12ms/step
# Epoch 107/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 861ms/epoch - 12ms/step
# Epoch 108/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 841ms/epoch - 12ms/step
# Epoch 109/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 876ms/epoch - 13ms/step
# Epoch 110/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 836ms/epoch - 12ms/step
# Epoch 111/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 829ms/epoch - 12ms/step
# Epoch 112/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 867ms/epoch - 13ms/step
# Epoch 113/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 835ms/epoch - 12ms/step
# Epoch 114/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 819ms/epoch - 12ms/step
# Epoch 115/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 863ms/epoch - 13ms/step
# Epoch 116/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 855ms/epoch - 12ms/step
# Epoch 117/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 833ms/epoch - 12ms/step
# Epoch 118/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 813ms/epoch - 12ms/step
# Epoch 119/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 820ms/epoch - 12ms/step
# Epoch 120/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 815ms/epoch - 12ms/step
# Epoch 121/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 816ms/epoch - 12ms/step
# Epoch 122/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 810ms/epoch - 12ms/step
# Epoch 123/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 876ms/epoch - 13ms/step
# Epoch 124/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 886ms/epoch - 13ms/step
# Epoch 125/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0019 - 831ms/epoch - 12ms/step
# Epoch 126/400
# 69/69 - 1s - loss: 0.0020 - val_loss: 0.0020 - 849ms/epoch - 12ms/step
# Epoch 127/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0020 - 920ms/epoch - 13ms/step
# Epoch 128/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0020 - 843ms/epoch - 12ms/step
# Epoch 129/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 861ms/epoch - 12ms/step
# Epoch 130/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 853ms/epoch - 12ms/step
# Epoch 131/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 826ms/epoch - 12ms/step
# Epoch 132/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0020 - 825ms/epoch - 12ms/step
# Epoch 133/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0020 - 864ms/epoch - 13ms/step
# Epoch 134/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0020 - 884ms/epoch - 13ms/step
# Epoch 135/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0020 - 858ms/epoch - 12ms/step
# Epoch 136/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 830ms/epoch - 12ms/step
# Epoch 137/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 846ms/epoch - 12ms/step
# Epoch 138/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 917ms/epoch - 13ms/step
# Epoch 139/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0020 - 852ms/epoch - 12ms/step
# Epoch 140/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 861ms/epoch - 12ms/step
# Epoch 141/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 858ms/epoch - 12ms/step
# Epoch 142/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 883ms/epoch - 13ms/step
# Epoch 143/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 843ms/epoch - 12ms/step
# Epoch 144/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 867ms/epoch - 13ms/step
# Epoch 145/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 858ms/epoch - 12ms/step
# Epoch 146/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0020 - 862ms/epoch - 12ms/step
# Epoch 147/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 830ms/epoch - 12ms/step
# Epoch 148/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 835ms/epoch - 12ms/step
# Epoch 149/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 816ms/epoch - 12ms/step
# Epoch 150/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0020 - 855ms/epoch - 12ms/step
# Epoch 151/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 887ms/epoch - 13ms/step
# Epoch 152/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 825ms/epoch - 12ms/step
# Epoch 153/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0020 - 874ms/epoch - 13ms/step
# Epoch 154/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 870ms/epoch - 13ms/step
# Epoch 155/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 830ms/epoch - 12ms/step
# Epoch 156/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 818ms/epoch - 12ms/step
# Epoch 157/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 824ms/epoch - 12ms/step
# Epoch 158/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 818ms/epoch - 12ms/step
# Epoch 159/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 819ms/epoch - 12ms/step
# Epoch 160/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 820ms/epoch - 12ms/step
# Epoch 161/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 820ms/epoch - 12ms/step
# Epoch 162/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 816ms/epoch - 12ms/step
# Epoch 163/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 822ms/epoch - 12ms/step
# Epoch 164/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0019 - 816ms/epoch - 12ms/step
# Epoch 165/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 866ms/epoch - 13ms/step
# Epoch 166/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 836ms/epoch - 12ms/step
# Epoch 167/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 924ms/epoch - 13ms/step
# Epoch 168/400
# 69/69 - 1s - loss: 0.0019 - val_loss: 0.0020 - 934ms/epoch - 14ms/step
# Epoch 169/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 833ms/epoch - 12ms/step
# Epoch 170/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 866ms/epoch - 13ms/step
# Epoch 171/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 827ms/epoch - 12ms/step
# Epoch 172/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 833ms/epoch - 12ms/step
# Epoch 173/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 828ms/epoch - 12ms/step
# Epoch 174/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 854ms/epoch - 12ms/step
# Epoch 175/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 831ms/epoch - 12ms/step
# Epoch 176/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 823ms/epoch - 12ms/step
# Epoch 177/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 824ms/epoch - 12ms/step
# Epoch 178/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 875ms/epoch - 13ms/step
# Epoch 179/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0019 - 813ms/epoch - 12ms/step
# Epoch 180/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0018 - 812ms/epoch - 12ms/step
# Epoch 181/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0018 - 830ms/epoch - 12ms/step
# Epoch 182/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0018 - 815ms/epoch - 12ms/step
# Epoch 183/400
# 69/69 - 1s - loss: 0.0018 - val_loss: 0.0018 - 817ms/epoch - 12ms/step
# Epoch 184/400
# 69/69 - 1s - loss: 0.0017 - val_loss: 0.0018 - 819ms/epoch - 12ms/step
# Epoch 185/400
# 69/69 - 1s - loss: 0.0017 - val_loss: 0.0018 - 829ms/epoch - 12ms/step
# Epoch 186/400
# 69/69 - 1s - loss: 0.0017 - val_loss: 0.0017 - 824ms/epoch - 12ms/step
# Epoch 187/400
# 69/69 - 1s - loss: 0.0017 - val_loss: 0.0017 - 809ms/epoch - 12ms/step
# Epoch 188/400
# 69/69 - 1s - loss: 0.0016 - val_loss: 0.0017 - 823ms/epoch - 12ms/step
# Epoch 189/400
# 69/69 - 1s - loss: 0.0016 - val_loss: 0.0016 - 823ms/epoch - 12ms/step
# Epoch 190/400
# 69/69 - 1s - loss: 0.0016 - val_loss: 0.0016 - 832ms/epoch - 12ms/step
# Epoch 191/400
# 69/69 - 1s - loss: 0.0016 - val_loss: 0.0016 - 828ms/epoch - 12ms/step
# Epoch 192/400
# 69/69 - 1s - loss: 0.0015 - val_loss: 0.0016 - 828ms/epoch - 12ms/step
# Epoch 193/400
# 69/69 - 1s - loss: 0.0015 - val_loss: 0.0016 - 828ms/epoch - 12ms/step
# Epoch 194/400
# 69/69 - 1s - loss: 0.0015 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 195/400
# 69/69 - 1s - loss: 0.0015 - val_loss: 0.0015 - 815ms/epoch - 12ms/step
# Epoch 196/400
# 69/69 - 1s - loss: 0.0015 - val_loss: 0.0015 - 857ms/epoch - 12ms/step
# Epoch 197/400
# 69/69 - 1s - loss: 0.0015 - val_loss: 0.0016 - 837ms/epoch - 12ms/step
# Epoch 198/400
# 69/69 - 1s - loss: 0.0015 - val_loss: 0.0015 - 843ms/epoch - 12ms/step
# Epoch 199/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 200/400
# 69/69 - 1s - loss: 0.0015 - val_loss: 0.0016 - 824ms/epoch - 12ms/step
# Epoch 201/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 817ms/epoch - 12ms/step
# Epoch 202/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 831ms/epoch - 12ms/step
# Epoch 203/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 872ms/epoch - 13ms/step
# Epoch 204/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 834ms/epoch - 12ms/step
# Epoch 205/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 206/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 829ms/epoch - 12ms/step
# Epoch 207/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 842ms/epoch - 12ms/step
# Epoch 208/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 813ms/epoch - 12ms/step
# Epoch 209/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 210/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0016 - 820ms/epoch - 12ms/step
# Epoch 211/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 212/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 837ms/epoch - 12ms/step
# Epoch 213/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0016 - 863ms/epoch - 13ms/step
# Epoch 214/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 215/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 832ms/epoch - 12ms/step
# Epoch 216/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 865ms/epoch - 13ms/step
# Epoch 217/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 819ms/epoch - 12ms/step
# Epoch 218/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 219/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 220/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 221/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 892ms/epoch - 13ms/step
# Epoch 222/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 917ms/epoch - 13ms/step
# Epoch 223/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 935ms/epoch - 14ms/step
# Epoch 224/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 889ms/epoch - 13ms/step
# Epoch 225/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 908ms/epoch - 13ms/step
# Epoch 226/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 867ms/epoch - 13ms/step
# Epoch 227/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 843ms/epoch - 12ms/step
# Epoch 228/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 849ms/epoch - 12ms/step
# Epoch 229/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 838ms/epoch - 12ms/step
# Epoch 230/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 845ms/epoch - 12ms/step
# Epoch 231/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 232/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 816ms/epoch - 12ms/step
# Epoch 233/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 826ms/epoch - 12ms/step
# Epoch 234/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 821ms/epoch - 12ms/step
# Epoch 235/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 236/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 237/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 829ms/epoch - 12ms/step
# Epoch 238/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 239/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 820ms/epoch - 12ms/step
# Epoch 240/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 830ms/epoch - 12ms/step
# Epoch 241/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 242/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 820ms/epoch - 12ms/step
# Epoch 243/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 244/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 245/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 246/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 247/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 248/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 249/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 250/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 251/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 252/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 826ms/epoch - 12ms/step
# Epoch 253/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 254/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 830ms/epoch - 12ms/step
# Epoch 255/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 819ms/epoch - 12ms/step
# Epoch 256/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0016 - 850ms/epoch - 12ms/step
# Epoch 257/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 258/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 259/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 260/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 821ms/epoch - 12ms/step
# Epoch 261/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 262/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 831ms/epoch - 12ms/step
# Epoch 263/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 264/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 820ms/epoch - 12ms/step
# Epoch 265/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 266/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 267/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 818ms/epoch - 12ms/step
# Epoch 268/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 269/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 270/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 826ms/epoch - 12ms/step
# Epoch 271/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 820ms/epoch - 12ms/step
# Epoch 272/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 273/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 274/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 275/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 821ms/epoch - 12ms/step
# Epoch 276/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 277/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 278/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 279/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 820ms/epoch - 12ms/step
# Epoch 280/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 808ms/epoch - 12ms/step
# Epoch 281/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 282/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 283/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0016 - 814ms/epoch - 12ms/step
# Epoch 284/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 821ms/epoch - 12ms/step
# Epoch 285/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 286/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 287/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 288/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 818ms/epoch - 12ms/step
# Epoch 289/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 290/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 291/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 818ms/epoch - 12ms/step
# Epoch 292/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 293/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 294/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 829ms/epoch - 12ms/step
# Epoch 295/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 816ms/epoch - 12ms/step
# Epoch 296/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 297/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 298/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 299/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 300/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 816ms/epoch - 12ms/step
# Epoch 301/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 302/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 817ms/epoch - 12ms/step
# Epoch 303/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 304/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 305/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 306/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 857ms/epoch - 12ms/step
# Epoch 307/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 308/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 309/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 310/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 311/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 312/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 313/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 818ms/epoch - 12ms/step
# Epoch 314/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 315/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 316/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 813ms/epoch - 12ms/step
# Epoch 317/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 820ms/epoch - 12ms/step
# Epoch 318/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 826ms/epoch - 12ms/step
# Epoch 319/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 320/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 321/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 830ms/epoch - 12ms/step
# Epoch 322/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 832ms/epoch - 12ms/step
# Epoch 323/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 821ms/epoch - 12ms/step
# Epoch 324/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 325/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 832ms/epoch - 12ms/step
# Epoch 326/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 327/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 826ms/epoch - 12ms/step
# Epoch 328/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 329/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 330/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 331/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 836ms/epoch - 12ms/step
# Epoch 332/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 837ms/epoch - 12ms/step
# Epoch 333/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 334/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 335/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 820ms/epoch - 12ms/step
# Epoch 336/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 819ms/epoch - 12ms/step
# Epoch 337/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 338/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 842ms/epoch - 12ms/step
# Epoch 339/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 826ms/epoch - 12ms/step
# Epoch 340/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 829ms/epoch - 12ms/step
# Epoch 341/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 826ms/epoch - 12ms/step
# Epoch 342/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 839ms/epoch - 12ms/step
# Epoch 343/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 830ms/epoch - 12ms/step
# Epoch 344/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 345/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 820ms/epoch - 12ms/step
# Epoch 346/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 817ms/epoch - 12ms/step
# Epoch 347/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 348/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 830ms/epoch - 12ms/step
# Epoch 349/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 350/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 853ms/epoch - 12ms/step
# Epoch 351/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 352/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 829ms/epoch - 12ms/step
# Epoch 353/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 829ms/epoch - 12ms/step
# Epoch 354/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 820ms/epoch - 12ms/step
# Epoch 355/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 356/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 357/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 358/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 820ms/epoch - 12ms/step
# Epoch 359/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 818ms/epoch - 12ms/step
# Epoch 360/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 361/400
# 69/69 - 1s - loss: 0.0014 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 362/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 363/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 364/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 820ms/epoch - 12ms/step
# Epoch 365/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 366/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 819ms/epoch - 12ms/step
# Epoch 367/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 368/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 823ms/epoch - 12ms/step
# Epoch 369/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 370/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 821ms/epoch - 12ms/step
# Epoch 371/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 372/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 373/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 821ms/epoch - 12ms/step
# Epoch 374/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 375/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 831ms/epoch - 12ms/step
# Epoch 376/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 814ms/epoch - 12ms/step
# Epoch 377/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 378/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 379/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 380/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 832ms/epoch - 12ms/step
# Epoch 381/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 382/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 383/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 384/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 385/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 386/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 828ms/epoch - 12ms/step
# Epoch 387/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 388/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 834ms/epoch - 12ms/step
# Epoch 389/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 830ms/epoch - 12ms/step
# Epoch 390/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 818ms/epoch - 12ms/step
# Epoch 391/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 822ms/epoch - 12ms/step
# Epoch 392/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 818ms/epoch - 12ms/step
# Epoch 393/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 394/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 818ms/epoch - 12ms/step
# Epoch 395/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 825ms/epoch - 12ms/step
# Epoch 396/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 818ms/epoch - 12ms/step
# Epoch 397/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 824ms/epoch - 12ms/step
# Epoch 398/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 827ms/epoch - 12ms/step
# Epoch 399/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 819ms/epoch - 12ms/step
# Epoch 400/400
# 69/69 - 1s - loss: 0.0013 - val_loss: 0.0015 - 848ms/epoch - 12ms/step

# %%
# save model
# sae.save(f'{model_path}/sae_{which}_lat{latent_dim}.h5')
# enc.save(f'{model_path}/enc_{which}_lat{latent_dim}.h5')
# dec.save(f'{model_path}/dec_{which}_lat{latent_dim}.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# load model
sae = keras.models.load_model(f'{model_path}/sae_{which}_lat{latent_dim}.h5')
dec = keras.models.load_model(f'{model_path}/dec_{which}_lat{latent_dim}.h5')
enc = keras.models.load_model(f'{model_path}/enc_{which}_lat{latent_dim}.h5')

# %% [markdown]
# # Results

# %%
# loss history
plt.plot(np.arange(1,epochs+1),fit_sae.history['loss'], 'k-', label='train')
plt.plot(np.arange(1,epochs+1),fit_sae.history['val_loss'], 'r--', label='valid')
plt.xlabel('epoch',fontsize=12)

plt.ylabel('loss',fontsize=12)
plt.yscale('log')
plt.legend()
plt.title(f'{output_path}/training history of self-attention AE',fontsize=15)
# Out:
# Text(0.5, 1.0, 'output/training history of self-attention AE')

# %%
# reconstruction errors
reconstr = (sae.predict(X_test, verbose=0)).reshape(-1,200)
rmse_ic = np.sqrt(np.mean((vmax*(X_test.reshape(-1,200) - reconstr))**2, axis=1))
fig, ax = plt.subplots(1,1,figsize=(6,4))
ax.hist(rmse_ic, bins=20)
ax.set_xlabel('$RMSE_{Ic}$')
ax.set_ylabel('Counts')
#ax[0].set_xlim(0,1)
# Out:
# Text(0, 0.5, 'Counts')

# %%
dataset = X_test
#preds = sae.predict(dataset, verbose=0)
index = 0

# %%
if which == 'both':
  fig, ax = plt.subplots(1,2,figsize=(6,6))
  pred = sae.predict(dataset[index:index+1], verbose=0).squeeze(axis=0)
  ax[0].plot(pred[:,0]*5, np.arange(0,10,0.05),'r--')
  ax[0].plot(dataset[index,:,0]*5, np.arange(0,10,0.05),'k-')
  ax[1].plot(pred[:,1]*254, np.arange(0,10,0.05),'r--')
  ax[1].plot(dataset[index,:,1]*254, np.arange(0,10,0.05),'k-')

else:
  plt.figure(figsize=(3,6))
  pred = sae.predict(dataset[index:index+1], verbose=0)
  plt.plot(pred.reshape(-1)*scale,np.arange(0,10,0.05),'r--')
  plt.plot(dataset[index].reshape(-1)*scale, np.linspace(0,10,200), 'k-')
  plt.xlabel(which, fontsize=12)
  plt.ylabel('depth (m)', fontsize=12)
  plt.ylim(10,0)
  plt.xlim(0,vmax)
index += 1

# %% [markdown]
# ## Visualize attention score of the first attention layer

# %%
dataset = X_test
attention = keras.Model(inputs=enc.inputs, outputs=enc.get_layer('enc_at1').output)
at_score = attention.predict(dataset, verbose=0)
at_score[1].shape
# Out:
# (1872, 3, 10, 10)

# %%
index = 0
cmap = 'inferno'
at_index = 1

# %%
from matplotlib import gridspec
#fig, ax = plt.subplots(1,3, figsize=(18,6))
fig = plt.figure(figsize=(6*(initial_heads+1), 6))
width_ratios = np.ones(initial_heads+1)
width_ratios[1:] = 2
gs = gridspec.GridSpec(1, initial_heads+1, width_ratios=width_ratios)
im_ratio = 200

input = dataset[index].reshape(-1)

reconstr = sae.predict(dataset[index:index+1], verbose=0).reshape(-1)
ax0 = plt.subplot(gs[0])
ax0.plot(input, np.linspace(0,10,200,endpoint=False),'k', label='input')
#cae_reconstr = cae.predict(input.reshape(1,200))
#ax0.plot(cae_reconstr.reshape(-1), np.linspace(0,10,200,endpoint=False), label='cae_reconstr', linestyle='--')
ax0.plot(reconstr, np.linspace(0,10,200,endpoint=False), label='sae_reconstr', linestyle='--')
ax0.set_ylabel('depth',fontsize=12)
ax0.set_xlabel(which,fontsize=12)
ax0.set_ylim(10,0)
#ax0.set_xlim(0,4)
ax0.set_yticks(np.linspace(0,11,11,endpoint=False))
ax0.grid()
ax0.legend()

for i in range(initial_heads):
  # attention matrix 1
  ax1 = plt.subplot(gs[i+1])
  im1 = ax1.imshow(at_score[1][index][i], cmap='viridis')
  ax1.set_xlabel('Pay attention to position i',fontsize=12)
  ax1.set_ylabel('Position',fontsize=12)
  plt.colorbar(im1, fraction=0.046*1,pad=0.04, ax=ax1)
  ax1.set_title(f'Attention matrix {i+1}',fontsize=15)
#plt.tight_layout()
index += 1
